# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_orig = pd.read_excel("../Paris housing Data Set 2 4050.xlsx")
data = data_orig.copy(deep=True)
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_total  floors  condition  \
# 0  221900.0       3.0        1.0       1180.0      5650.0     1.0        3.0
# 1  538000.0       3.0        NaN       2570.0      7242.0     2.0        3.0
# 2  180000.0       2.0        1.0        770.0     10000.0     1.0        3.0
# 3  604000.0       4.0        3.0       1960.0      5000.0     1.0        5.0
# 4  510000.0       3.0        2.0       1680.0      8080.0     1.0        3.0
#
#    grade   built  renovated  living_area_sqft
# 0      7  1955.0          0            1340.0
# 1      7  1951.0       1991            1690.0
# 2      6  1933.0          0            2720.0
# 3      7  1965.0          0            1360.0
# 4      8  1987.0          0            1800.0

# %%
sns.pairplot(data)

# %%
import scipy.stats as stat 
import scipy.optimize as opt
import numpy as np

# %%
np.random.seed(42)
data = pd.DataFrame({
    "A":np.random.normal(20,50,1000),
    "B":np.random.randint(10,100,1000),
    "C":np.random.uniform(0,80,1000),
    "D":np.random.choice(["New","Refurbrished","used"],1000)
})

# %%
data.dtypes
# Out:
# A    float64
# B      int32
# C    float64
# D     object
# dtype: object

# %%
#sns.pairplot(data, hue="D", kind="kde")
sns.pairplot(data, kind="kde")

# %%
data.corr(numeric_only=True)
# Out:
#           A         B         C
# A  1.000000  0.059885  0.001069
# B  0.059885  1.000000 -0.003860
# C  0.001069 -0.003860  1.000000

# %%
sns.histplot(data['D'], bins=20, kde=True)
plt.xlabel('Values in d')
plt.ylabel('Frequency')
plt.title('Histogram of Column d')
plt.show()
